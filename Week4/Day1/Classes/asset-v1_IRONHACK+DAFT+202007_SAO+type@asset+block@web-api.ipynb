# %%
import pandas as pd
import os
# ^^^ pyforest auto-imports - don't write above this line
import pandas as pd
import os

# %% [markdown]
# # API Wrappers

# %% [markdown]
# ## Dealing with `keys` in code
#
# Usually, when you access an API, you'll use some password or `key`.
#
# There's a package called `dotenv` that helps you hide your keys inside a file.

# %% [markdown]
# - Install dotenv `!pip install dotenv`
# - Create a file with a `.env` extension and variables inside of it like
# ```
# API_KEY="l1noPOPAixCPM"
# API_SECRET="GraGq0zrGhs1qvbA0xQXsZBKuTkK5MJ"
# ```
# - run dotenv.load_dotenv('filename.env')
# - now if you run os.getenv('API_KEY'), it will contain the string 'l1noPOPAixCPM'
# - the idea is that you can upload your code to Github and **DON'T** upload the `.env` file

# %%
from dotenv import load_dotenv, find_dotenv

# %%
load_dotenv(find_dotenv())
# Out:
# True

# %%
import os

# %%
my_pwd = os.getenv('PASSWORD')

# %%
my_pwd
# Out:
# 'qwerty12345'

# %%
# after running the code below, you'll have access to the variables inside this file
load_dotenv('keys_api.env')
# Out:
# True

# %%
import os
# os.getenv('API_KEY')

# %%
# you can safely store it inside a variable and use it inside your API
API_KEY = os.getenv('API_KEY')

# %% [markdown]
# ## List of API wrappers
#
# - This is a list of some known python packages that facilitates the use of some APIs:
# https://github.com/realpython/list-of-python-api-wrappers
#
# - But there are much more than that. You just have to look for it. Here's a list of some public APIs grouped by type: https://github.com/public-apis/public-apis. Maybe you can find an API wrapper for those too. You just need to search google something like: `name_of_the_api python wrapper`
#
# - API para o `Portal da Transparência` (Brasil): http://www.transparencia.gov.br/swagger-ui.html
#
# - Here's another list of fun APIs: https://apilist.fun/

# %% [markdown]
# # Use Cases

# %% [markdown]
# ## OMDB:
#
# http://www.omdbapi.com/

# %% [markdown]
# https://github.com/dgilland/omdb.py
#
# Install API wrapper: `!pip install omdb`

# %%
load_dotenv('keys_api.env')
# Out:
# True

# %%
omdb_key = os.getenv('OMDB_IRONHACK_KEY')

# %%
from omdb import OMDBClient

client = OMDBClient(apikey=os.getenv('OMDB_IRONHACK_KEY'))

# %%
client.search('Friends')
# Out:
# [{'title': 'Friends',
#   'year': '1994–2004',
#   'imdb_id': 'tt0108778',
#   'type': 'series',
#   'poster': 'https://m.media-amazon.com/images/M/MV5BNDVkYjU0MzctMWRmZi00NTkxLTgwZWEtOWVhYjZlYjllYmU4XkEyXkFqcGdeQXVyNTA4NzY1MzY@._V1_SX300.jpg'},
#  {'title': 'Friends with Benefits',
#   'year': '2011',
#   'imdb_id': 'tt1632708',
#   'type': 'movie',
#   'poster': 'https://m.media-amazon.com/images/M/MV5BMTQ2MzQ0NTk4N15BMl5BanBnXkFtZTcwMDc2NDYzNQ@@._V1_SX300.jpg'},
#  {'title': 'Just Friends',
#   'year': '2005',
#   'imdb_id': 'tt0433400',
#   'type': 'movie',
#   'poster': 'https://m.media-amazon.com/images/M/MV5BMjA0Mzg2NjUzMl5BMl5BanBnXkFtZTcwNDg2ODUzMQ@@._V1_SX300.jpg'},
#  {'title': 'How to Lose Friends & Alienate People',
#   'year': '2008',
#   'imdb_id': 'tt0455538',
#   'type': 'movie',
#   'poster': 'https://m.media-amazon.com/images/M/MV5BMjY0MzFmMDgtY2ZiOC00M2QyLWFmOWMtOTBmZWY4OWE2YTYzXkEyXkFqcGdeQXVyMjA5MTIzMjQ@._V1_SX300.jpg'},
#  {'title': 'Friends with Kids',
# ...

# %%
client.get(title='Friends')['poster']
# Out:
# 'https://m.media-amazon.com/images/M/MV5BNDVkYjU0MzctMWRmZi00NTkxLTgwZWEtOWVhYjZlYjllYmU4XkEyXkFqcGdeQXVyNTA4NzY1MzY@._V1_SX300.jpg'

# %%
client.get(title='Titanic')['poster']
# Out:
# 'https://m.media-amazon.com/images/M/MV5BMDdmZGU3NDQtY2E5My00ZTliLWIzOTUtMTY4ZGI1YjdiNjk3XkEyXkFqcGdeQXVyNTA4NzY1MzY@._V1_SX300.jpg'

# %%
url = client.get(title='Titanic')['poster']

# %%
url
# Out:
# 'https://m.media-amazon.com/images/M/MV5BMDdmZGU3NDQtY2E5My00ZTliLWIzOTUtMTY4ZGI1YjdiNjk3XkEyXkFqcGdeQXVyNTA4NzY1MzY@._V1_SX300.jpg'

# %%
import requests
from PIL import Image

response = requests.get(url, stream=True)
Image.open(response.raw)
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=300x447 at 0x2DF9CF677B8>

# %%
client.search('interstellar')
# Out:
# [{'title': 'Interstellar',
#   'year': '2014',
#   'imdb_id': 'tt0816692',
#   'type': 'movie',
#   'poster': 'https://m.media-amazon.com/images/M/MV5BZjdkOTU3MDktN2IxOS00OGEyLWFmMjktY2FiMmZkNWIyODZiXkEyXkFqcGdeQXVyMTMxODk2OTU@._V1_SX300.jpg'},
#  {'title': 'The Science of Interstellar',
#   'year': '2015',
#   'imdb_id': 'tt4415360',
#   'type': 'movie',
#   'poster': 'https://m.media-amazon.com/images/M/MV5BMDFhNzU4MTMtYzZmNS00ZDEzLTg2MjQtYmUzZDA1ZWU4OTkzXkEyXkFqcGdeQXVyNDQ2MTMzODA@._V1_SX300.jpg'},
#  {'title': 'Interstellar Wars',
#   'year': '2016',
#   'imdb_id': 'tt5083736',
#   'type': 'movie',
#   'poster': 'https://m.media-amazon.com/images/M/MV5BMzE5MmExYzMtYjQxYi00ZDlkLTkzMTYtMWQzNTZkMjBiYWI2L2ltYWdlXkEyXkFqcGdeQXVyNTM3MDMyMDQ@._V1_SX300.jpg'},
#  {'title': 'Lolita from Interstellar Space',
#   'year': '2014',
#   'imdb_id': 'tt3506492',
#   'type': 'movie',
# ...

# %%
url = client.get(title='Interstellar')['poster']

# %%
client.get(title='Interstellar')
# Out:
# {'title': 'Interstellar',
#  'year': '2014',
#  'rated': 'PG-13',
#  'released': '07 Nov 2014',
#  'runtime': '169 min',
#  'genre': 'Adventure, Drama, Sci-Fi, Thriller',
#  'director': 'Christopher Nolan',
#  'writer': 'Jonathan Nolan, Christopher Nolan',
#  'actors': 'Ellen Burstyn, Matthew McConaughey, Mackenzie Foy, John Lithgow',
#  'plot': "A team of explorers travel through a wormhole in space in an attempt to ensure humanity's survival.",
#  'language': 'English',
#  'country': 'USA, UK, Canada',
#  'awards': 'Won 1 Oscar. Another 43 wins & 147 nominations.',
#  'poster': 'https://m.media-amazon.com/images/M/MV5BZjdkOTU3MDktN2IxOS00OGEyLWFmMjktY2FiMmZkNWIyODZiXkEyXkFqcGdeQXVyMTMxODk2OTU@._V1_SX300.jpg',
#  'ratings': [{'source': 'Internet Movie Database', 'value': '8.6/10'},
#   {'source': 'Rotten Tomatoes', 'value': '72%'},
#   {'source': 'Metacritic', 'value': '74/100'}],
#  'metascore': '74',
#  'imdb_rating': '8.6',
#  'imdb_votes': '1,448,390',
# ...

# %%
client.search_series('Friends')
# Out:
# [{'title': 'Friends',
#   'year': '1994–2004',
#   'imdb_id': 'tt0108778',
#   'type': 'series',
#   'poster': 'https://m.media-amazon.com/images/M/MV5BNDVkYjU0MzctMWRmZi00NTkxLTgwZWEtOWVhYjZlYjllYmU4XkEyXkFqcGdeQXVyNTA4NzY1MzY@._V1_SX300.jpg'},
#  {'title': "Foster's Home for Imaginary Friends",
#   'year': '2004–2009',
#   'imdb_id': 'tt0419326',
#   'type': 'series',
#   'poster': 'https://m.media-amazon.com/images/M/MV5BNjYyNGFjOTctYzFmNC00NzdmLThhMDgtNjEzZTRmNzA3ODc5XkEyXkFqcGdeQXVyNjk1Njg5NTA@._V1_SX300.jpg'},
#  {'title': 'Friends from College',
#   'year': '2017–',
#   'imdb_id': 'tt5565334',
#   'type': 'series',
#   'poster': 'https://m.media-amazon.com/images/M/MV5BMjMyNjgxNDc3MV5BMl5BanBnXkFtZTgwNDUyMzQ2NjM@._V1_SX300.jpg'},
#  {'title': 'Happy Tree Friends',
#   'year': '2000–',
#   'imdb_id': 'tt0770762',
#   'type': 'series',
# ...

# %%
response = requests.get(url, stream=True)
Image.open(response.raw)
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=300x444 at 0x2DF9CE61DD8>

# %% [markdown]
# ## Spotify

# %% [markdown]
# Install spotipy: `pip install spotipy`

# %% [markdown]
# Read its documentation: https://spotipy.readthedocs.io/en/2.14.0/

# %% [markdown]
# If you read the documentation, it tells you to get your `access key` at https://developer.spotify.com/documentation/web-api/. You can view the `quick-start` tab or follow the guidelines here.
#
# - Click on `Dashboard`
# - Log in to your Spotify account
# - Create an APP
# - Collect your `Client ID` and `Client Secret` (click on SHOW CLIENT SECRET)
# - Click on `Edit Settings` on your app's dashboard
#     - You have to insert a `redirect_uri` (I've put: https://www.google.com. You can put anything.)
# - Find your username ID in your profile settings.
#
#
# - Code Samples: https://github.com/plamere/spotipy/tree/master/examples

# %%
from dotenv import load_dotenv

# %%
load_dotenv('keys_api.env')
# Out:
# True

# %%
client_id = os.getenv('spotify_key_dataft')
client_secret = os.getenv('spotify_secret_dataft')

# %%
redirect_uri = 'https://www.google.com/'
username = '4hr4bfu1lyrx7c2godprqqx2v'

# %%
import spotipy
from spotipy import util
from spotipy.oauth2 import SpotifyClientCredentials, SpotifyOAuth

# https://developer.spotify.com/documentation/general/guides/scopes/#user-read-recently-played
scope = 'user-library-read playlist-read-private user-read-playback-state user-modify-playback-state'

# %% [markdown]
# ### Authentication

# %%
token = util.prompt_for_user_token(username,
                                   scope,
                                   client_id=client_id,
                                   client_secret=client_secret,
                                   redirect_uri=redirect_uri)

sp = spotipy.Spotify(auth=token)
# Out:
# Enter the URL you were redirected to: https://www.google.com/?code=AQBnfNgchT2K1_YzhlbPFZdOLbL8bpl3KyzIVYzNuM0vP--S8bWMun6V5_4oyC_QRPQJfD650JF40oKk_LaS7Ir8Qc1OE9UzCO8BqsGNsm43Le6Yrj2EH5OgkLoR-YaG7aDZyQ5YxZ8X1nb_Q3Mj0_spC9lMWvZjVlmmmoqa4jaaWx-mIY-NNot_5P-gkN3XXZQaqeKYFD5w59GKH7AXEu1KKq6A9hFXK9ce6YhBXg7Pg-hUzuKUWgw0VAN97OM3W1S6HwwpZSNMiks_qI0KUZYm61SRNpn4OXaX

# %% [markdown]
# ### Users `current_playing` status

# %%
sp.currently_playing()

# %%
sp.currently_playing()
# Out:
# {'timestamp': 1599507351201,
#  'context': {'external_urls': {'spotify': 'https://open.spotify.com/playlist/0Vj6tV1xKC9KPeaLm8iPFK'},
#   'href': 'https://api.spotify.com/v1/playlists/0Vj6tV1xKC9KPeaLm8iPFK',
#   'type': 'playlist',
#   'uri': 'spotify:playlist:0Vj6tV1xKC9KPeaLm8iPFK'},
#  'progress_ms': 14896,
#  'item': {'album': {'album_type': 'album',
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3Qyjq5eQNKo5tHVmXyhvtB'},
#      'href': 'https://api.spotify.com/v1/artists/3Qyjq5eQNKo5tHVmXyhvtB',
#      'id': '3Qyjq5eQNKo5tHVmXyhvtB',
#      'name': 'Netinho',
#      'type': 'artist',
#      'uri': 'spotify:artist:3Qyjq5eQNKo5tHVmXyhvtB'}],
#    'available_markets': [],
#    'external_urls': {'spotify': 'https://open.spotify.com/album/6EJ98J4NcmLjsjCx39q49V'},
#    'href': 'https://api.spotify.com/v1/albums/6EJ98J4NcmLjsjCx39q49V',
#    'id': '6EJ98J4NcmLjsjCx39q49V',
#    'images': [{'height': 640,
# ...

# %%
sp.pause_playback()

# %%
sp.currently_playing()['item']['name']
# Out:
# 'Milla - Ao Vivo'

# %%
sp.currently_playing()['is_playing']
# Out:
# True

# %%
sp.currently_playing()['item']['album']['images']
# Out:
# [{'height': 640,
#   'url': 'https://i.scdn.co/image/ab67616d0000b27367edb6edaf3946be6a6b75d0',
#   'width': 640},
#  {'height': 300,
#   'url': 'https://i.scdn.co/image/ab67616d00001e0267edb6edaf3946be6a6b75d0',
#   'width': 300},
#  {'height': 64,
#   'url': 'https://i.scdn.co/image/ab67616d0000485167edb6edaf3946be6a6b75d0',
#   'width': 64}]

# %% [markdown]
# ### Skip song

# %%
sp.next_track()

# %%
sp.currently_playing()
# Out:
# {'timestamp': 1599507619397,
#  'context': {'external_urls': {'spotify': 'https://open.spotify.com/playlist/0Vj6tV1xKC9KPeaLm8iPFK'},
#   'href': 'https://api.spotify.com/v1/playlists/0Vj6tV1xKC9KPeaLm8iPFK',
#   'type': 'playlist',
#   'uri': 'spotify:playlist:0Vj6tV1xKC9KPeaLm8iPFK'},
#  'progress_ms': 15447,
#  'item': {'album': {'album_type': 'album',
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7iJl63aJyNd8C6NZlMv6kp'},
#      'href': 'https://api.spotify.com/v1/artists/7iJl63aJyNd8C6NZlMv6kp',
#      'id': '7iJl63aJyNd8C6NZlMv6kp',
#      'name': 'Tchakabum',
#      'type': 'artist',
#      'uri': 'spotify:artist:7iJl63aJyNd8C6NZlMv6kp'}],
#    'available_markets': [],
#    'external_urls': {'spotify': 'https://open.spotify.com/album/4OFbq9zAblwR8v26BdHb9p'},
#    'href': 'https://api.spotify.com/v1/albums/4OFbq9zAblwR8v26BdHb9p',
#    'id': '4OFbq9zAblwR8v26BdHb9p',
#    'images': [{'height': 640,
# ...

# %%
sp.currently_playing().keys()
# Out:
# dict_keys(['timestamp', 'context', 'progress_ms', 'item', 'currently_playing_type', 'actions', 'is_playing'])

# %%
sp.pause_playback()

# %%
sp.currently_playing()['item'].keys()
# Out:
# dict_keys(['album', 'artists', 'available_markets', 'disc_number', 'duration_ms', 'explicit', 'external_ids', 'external_urls', 'href', 'id', 'is_local', 'name', 'popularity', 'preview_url', 'track_number', 'type', 'uri'])

# %%
sp.currently_playing()['item']['album']['id']
# Out:
# '4OFbq9zAblwR8v26BdHb9p'

# %%
[(item['name'], item['duration_ms'], item['id']) for item in sp.album_tracks(sp.currently_playing()['item']['album']['id'])['items']]
# Out:
# [('Explosao', 182693, '198vEZJYqlOtiWw2e1mPmq'),
#  ('De Bailao', 190893, '3ubq97W59mdKVFvdMCTvJK'),
#  ('Catuca', 168520, '2uYr3N2Esc2LR24045ZvBs'),
#  ('Molenguinho', 165013, '2NILa9sm21Dc7ybx52tfBs'),
#  ('Heavy Samba', 201813, '5UmxgSaFKwfJZS2W5repiC'),
#  ('Curupaco', 207813, '5bsF5DA5h865DDMFw24zJE'),
#  ('Rebolado E Assim', 227093, '4HNBYQuLpMxcy48vQ6n59n'),
#  ('Umbigo', 175613, '4sXE5hwJSZMZqbNsnYcSw7'),
#  ('Sarado', 204386, '2GxpWJd6S0zQLGGujyFrSW'),
#  ('Pagodinho Gostoso', 192946, '5c1Uk5rrlDiUz3XWM4iGFY'),
#  ('James Brown', 207480, '6jTcO0ts4AZdFZWCZsgOLa'),
#  ('Abraçadinho', 233466, '0zsvGSBwL9KdZ6DBK8egcb'),
#  ('Vixi Maria', 220880, '72bn6yUAbp2VJUEZiY2ADd'),
#  ('Tesouro De Pirata / Dança Da Mãozinha', 539333, '5zTp4oUIR8btu63oM0Pvss')]

# %% [markdown]
# ### Get playlist tracks

# %%
# playlist
playlist_id = '5lcYGGVFmCcHfU75XGXJMH'

# %%
sp.playlist_tracks(playlist_id)['items'][2]['track']['id']
# Out:
# '50KpZ6oMPMwuOgpAg1bA0K'

# %% [markdown]
# ### Get Audio Features

# %%
sp.audio_features([sp.playlist_tracks(playlist_id)['items'][2]['track']['id'], 
                   '198vEZJYqlOtiWw2e1mPmq'])
# Out:
# [{'danceability': 0.251,
#   'energy': 0.0575,
#   'key': 9,
#   'loudness': -16.985,
#   'mode': 0,
#   'speechiness': 0.0293,
#   'acousticness': 0.605,
#   'instrumentalness': 0.922,
#   'liveness': 0.098,
#   'valence': 0.0371,
#   'tempo': 95.947,
#   'type': 'audio_features',
#   'id': '50KpZ6oMPMwuOgpAg1bA0K',
#   'uri': 'spotify:track:50KpZ6oMPMwuOgpAg1bA0K',
#   'track_href': 'https://api.spotify.com/v1/tracks/50KpZ6oMPMwuOgpAg1bA0K',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/50KpZ6oMPMwuOgpAg1bA0K',
#   'duration_ms': 219093,
#   'time_signature': 4},
#  {'danceability': 0.662,
#   'energy': 0.9,
#   'key': 4,
#   'loudness': -4.3,
#   'mode': 1,
#   'speechiness': 0.107,
#   'acousticness': 0.508,
#   'instrumentalness': 0.000889,
#   'liveness': 0.345,
#   'valence': 0.84,
#   'tempo': 135.868,
#   'type': 'audio_features',
#   'id': '198vEZJYqlOtiWw2e1mPmq',
#   'uri': 'spotify:track:198vEZJYqlOtiWw2e1mPmq',
# ...

# %%
pd.DataFrame(sp.audio_features([sp.playlist_tracks(playlist_id)['items'][2]['track']['id'], 
                   '198vEZJYqlOtiWw2e1mPmq']))
# Out:
# c:\programas\anaconda3\lib\site-packages\numpy\_distributor_init.py:32: UserWarning: loaded more than 1 DLL from .libs:
# c:\programas\anaconda3\lib\site-packages\numpy\.libs\libopenblas.PYQHXLVVQ7VESDPUVUADXEVJOBGHJPAY.gfortran-win_amd64.dll
# c:\programas\anaconda3\lib\site-packages\numpy\.libs\libopenblas.TXA6YQSD3GCQQC22GEQ54J2UDCXDXHWN.gfortran-win_amd64.dll
#   stacklevel=1)
#    danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0         0.251  0.0575    9   -16.985     0       0.0293         0.605
# 1         0.662  0.9000    4    -4.300     1       0.1070         0.508
#
#    instrumentalness  liveness  valence    tempo            type  \
# 0          0.922000     0.098   0.0371   95.947  audio_features
# 1          0.000889     0.345   0.8400  135.868  audio_features
#
#                        id                                   uri  \
# 0  50KpZ6oMPMwuOgpAg1bA0K  spotify:track:50KpZ6oMPMwuOgpAg1bA0K
# ...

# %%
sp.current_user()
# Out:
# {'display_name': 'andreaguiar',
#  'external_urls': {'spotify': 'https://open.spotify.com/user/4hr4bfu1lyrx7c2godprqqx2v'},
#  'followers': {'href': None, 'total': 0},
#  'href': 'https://api.spotify.com/v1/users/4hr4bfu1lyrx7c2godprqqx2v',
#  'id': '4hr4bfu1lyrx7c2godprqqx2v',
#  'images': [],
#  'type': 'user',
#  'uri': 'spotify:user:4hr4bfu1lyrx7c2godprqqx2v'}

# %%
sp.user('andreaguiar')
# Out:
# {'display_name': 'Andre Aguiar',
#  'external_urls': {'spotify': 'https://open.spotify.com/user/andreaguiar'},
#  'followers': {'href': None, 'total': 7},
#  'href': 'https://api.spotify.com/v1/users/andreaguiar',
#  'id': 'andreaguiar',
#  'images': [{'height': None,
#    'url': 'https://scontent-ort2-1.xx.fbcdn.net/v/t1.0-1/p320x320/68391745_10157519970154444_1569014135197270016_n.jpg?_nc_cat=101&_nc_sid=0c64ff&_nc_ohc=ycUtD7HsA38AX996Mu_&_nc_ht=scontent-ort2-1.xx&tp=6&oh=067635a5bf1267262b79d9c9ed160298&oe=5F7D96D5',
#    'width': None}],
#  'type': 'user',
#  'uri': 'spotify:user:andreaguiar'}

# %% [markdown]
# ### Get top tracks given artist URI

# %%
sp.artist_top_tracks('3Qyjq5eQNKo5tHVmXyhvtB')['tracks'][5]['name']
# Out:
# 'Prefixo De Verão / We Are The World Of Carnaval / Um Frevo Novo - Ao Vivo'

# %%
sp.artist_related_artists('3Qyjq5eQNKo5tHVmXyhvtB')['artists'][4]['name']
# Out:
# 'Terra Samba'

# %%
# podcast episodes
sp.show_episodes('1JdkD0ZoZ52KjwdR0b1WoT')
# Out:
# {'href': 'https://api.spotify.com/v1/shows/1JdkD0ZoZ52KjwdR0b1WoT/episodes?offset=0&limit=50',
#  'items': [{'audio_preview_url': 'https://p.scdn.co/mp3-preview/ab24e5efff844af72337f8ad273a7cc5d937497d',
#    'description': 'All good things must come to an end, including this podcast. This is the last episode we plan to release, and it doesn’t cover data science—it’s mostly reminiscing, thanking our wonderful audience (that’s you!), and marveling at how this thing that started out as a side project grew into a huge part of our lives for over 5 years.  It’s been a ride, and a real pleasure and privilege to talk to you each week. Thanks, best wishes, and good night!  —Katie and Ben',
#    'duration_ms': 2144549,
#    'explicit': False,
#    'external_urls': {'spotify': 'https://open.spotify.com/episode/7wQLgStzNkjIbeSUAv6ePG'},
#    'href': 'https://api.spotify.com/v1/episodes/7wQLgStzNkjIbeSUAv6ePG',
#    'id': '7wQLgStzNkjIbeSUAv6ePG',
#    'images': [{'height': 640,
# ...

# %%
sp.add_to_queue('0Em8m9kRctyH9S3MTXAHvY')
sp.next_track()

# %%
sp.pause_playback()

# %%
sp.volume(15)

# %% [markdown]
# ## Twitter API

# %% [markdown]
# Install wrapper: `!pip install tweepy`

# %% [markdown]
# ### Read the docs
#
# - Twitter API: https://developer.twitter.com/en/docs
# - Getting started: https://developer.twitter.com/en/docs/basics/getting-started
# - Generate an APP
# - Get your KEYs and TOKENs
#
# - **READ the tweepy documentation**: http://tweepy.readthedocs.io/

# %% [markdown]
# https://developer.twitter.com/en/docs/labs/filtered-stream/quick-start

# %% [markdown]
# https://towardsdatascience.com/how-to-access-twitters-api-using-tweepy-5a13a206683b

# %%
import tweepy

API_KEY= os.getenv('API_KEY')
API_SECRET=os.getenv('API_SECRET')
ACCESS_TOKEN=os.getenv('ACCESS_TOKEN')
ACCESS_TOKEN_SECRET=os.getenv('ACCESS_TOKEN_SECRET')

auth = tweepy.OAuthHandler(API_KEY, API_SECRET)
auth.set_access_token(ACCESS_TOKEN, ACCESS_TOKEN_SECRET)
api = tweepy.API(auth, wait_on_rate_limit=True, wait_on_rate_limit_notify=True)

# %% [markdown]
# ### Verify Credentials

# %%
try:
    api.verify_credentials()
    print("Authentication OK")
except:
    print("Error during authentication")
# Out:
# Authentication OK

# %% [markdown]
# ### Get user

# %%
type(api.get_user('andreaguiarr'))
# Out:
# tweepy.models.User

# %%
user = api.get_user('andreaguiarr')
user
# Out:
# User(_api=<tweepy.api.API object at 0x0000021B6EADC7F0>, _json={'id': 127961954, 'id_str': '127961954', 'name': 'André Aguiar', 'screen_name': 'andreaguiarr', 'location': '', 'profile_location': None, 'description': '', 'url': None, 'entities': {'description': {'urls': []}}, 'protected': False, 'followers_count': 22, 'friends_count': 37, 'listed_count': 0, 'created_at': 'Tue Mar 30 18:39:33 +0000 2010', 'favourites_count': 1, 'utc_offset': None, 'time_zone': None, 'geo_enabled': False, 'verified': False, 'statuses_count': 2, 'lang': None, 'status': {'created_at': 'Sat Sep 05 20:07:01 +0000 2020', 'id': 1302337462333845504, 'id_str': '1302337462333845504', 'text': '#acertômizeravi #chicletêro #eusôdabahia #cansado #Vamp_s2_Friends #xingandomuito https://t.co/VNPASk4vv6', 'truncated': False, 'entities': {'hashtags': [{'text': 'acertômizeravi', 'indices': [0, 15]}, {'text': 'chicletêro', 'indices': [16, 27]}, {'text': 'eusôdabahia', 'indices': [28, 40]}, {'text': 'cansado', 'indices': [
# ...

# %%
user.followers_count
# Out:
# 22

# %% [markdown]
# `user` will be an object. You'll have to learn how to handle it by searching for its methods and attributes.

# %% [markdown]
# ### ._json

# %%
user._json
# Out:
# {'id': 127961954,
#  'id_str': '127961954',
#  'name': 'André Aguiar',
#  'screen_name': 'andreaguiarr',
#  'location': '',
#  'profile_location': None,
#  'description': '',
#  'url': None,
#  'entities': {'description': {'urls': []}},
#  'protected': False,
#  'followers_count': 22,
#  'friends_count': 37,
#  'listed_count': 0,
#  'created_at': 'Tue Mar 30 18:39:33 +0000 2010',
#  'favourites_count': 1,
#  'utc_offset': None,
#  'time_zone': None,
#  'geo_enabled': False,
#  'verified': False,
#  'statuses_count': 2,
#  'lang': None,
#  'status': {'created_at': 'Sat Sep 05 20:07:01 +0000 2020',
#   'id': 1302337462333845504,
#   'id_str': '1302337462333845504',
#   'text': '#acertômizeravi #chicletêro #eusôdabahia #cansado #Vamp_s2_Friends #xingandomuito https://t.co/VNPASk4vv6',
#   'truncated': False,
#   'entities': {'hashtags': [{'text': 'acertômizeravi', 'indices': [0, 15]},
#     {'text': 'chicletêro', 'indices': [16, 27]},
#     {'text': 'eusôdabahia', 'indices': [28, 40]},
# ...

# %% [markdown]
# ### Get user's friends list

# %%
user.friends_count
# Out:
# 37

# %%
friends = user.friends()
friends
# Out:
# [User(_api=<tweepy.api.API object at 0x0000021B6EADC7F0>, _json={'id': 291726396, 'id_str': '291726396', 'name': 'Donato Notarnicola', 'screen_name': 'dnnetto', 'location': '', 'description': '', 'url': None, 'entities': {'description': {'urls': []}}, 'protected': True, 'followers_count': 83, 'friends_count': 380, 'listed_count': 0, 'created_at': 'Mon May 02 14:31:04 +0000 2011', 'favourites_count': 57, 'utc_offset': None, 'time_zone': None, 'geo_enabled': False, 'verified': False, 'statuses_count': 89, 'lang': None, 'status': {'created_at': 'Sat Sep 05 20:07:36 +0000 2020', 'id': 1302337606961725440, 'id_str': '1302337606961725440', 'text': '@andreaguiarr 🤣', 'truncated': False, 'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [{'screen_name': 'andreaguiarr', 'name': 'André Aguiar', 'id': 127961954, 'id_str': '127961954', 'indices': [0, 13]}], 'urls': []}, 'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>', 'in_reply_to_status_id': 130233
# ...

# %%
[friend._json['id'] for friend in friends]
# Out:
# [291726396,
#  2688124086,
#  25073877,
#  128372940,
#  819876321589415937,
#  1184633528081879040,
#  1109849507125215232,
#  1109282952037498883,
#  114911401,
#  1152703346,
#  289663535,
#  326912209,
#  352546807,
#  259379883,
#  1037011,
#  126190290,
#  69382909,
#  24062810,
#  17240425,
#  216377223]

# %%
api.get_user('291726396')._json
# Out:
# {'id': 291726396,
#  'id_str': '291726396',
#  'name': 'Donato Notarnicola',
#  'screen_name': 'dnnetto',
#  'location': '',
#  'profile_location': None,
#  'description': '',
#  'url': None,
#  'entities': {'description': {'urls': []}},
#  'protected': True,
#  'followers_count': 83,
#  'friends_count': 380,
#  'listed_count': 0,
#  'created_at': 'Mon May 02 14:31:04 +0000 2011',
#  'favourites_count': 57,
#  'utc_offset': None,
#  'time_zone': None,
#  'geo_enabled': False,
#  'verified': False,
#  'statuses_count': 89,
#  'lang': None,
#  'status': {'created_at': 'Sat Sep 05 20:07:36 +0000 2020',
#   'id': 1302337606961725440,
#   'id_str': '1302337606961725440',
#   'text': '@andreaguiarr 🤣',
#   'truncated': False,
#   'entities': {'hashtags': [],
#    'symbols': [],
#    'user_mentions': [{'screen_name': 'andreaguiarr',
#      'name': 'André Aguiar',
#      'id': 127961954,
#      'id_str': '127961954',
#      'indices': [0, 13]}],
#    'urls': []},
# ...

# %% [markdown]
# ### Send a tweet

# %%
comment = '#spotifynãofunfou #chateado #paçoca_yuri #portugal_ta_calor #feriado #lewagon'

api.update_status(comment)
# Out:
# Status(_api=<tweepy.api.API object at 0x0000021B6EADC7F0>, _json={'created_at': 'Mon Sep 07 19:03:44 +0000 2020', 'id': 1303046310426300416, 'id_str': '1303046310426300416', 'text': '#spotifynãofunfou #chateado #paçoca_yuri #portugal_ta_calor #feriado #lewagon', 'truncated': False, 'entities': {'hashtags': [{'text': 'spotifynãofunfou', 'indices': [0, 17]}, {'text': 'chateado', 'indices': [18, 27]}, {'text': 'paçoca_yuri', 'indices': [28, 40]}, {'text': 'portugal_ta_calor', 'indices': [41, 59]}, {'text': 'feriado', 'indices': [60, 68]}, {'text': 'lewagon', 'indices': [69, 77]}], 'symbols': [], 'user_mentions': [], 'urls': []}, 'source': '<a href="https://cs50.harvard.edu/" rel="nofollow">sentimentsAPI</a>', 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 127961954, 'id_str': '127961954', 'name': 'André Aguiar', 'screen_name': 'andreaguiarr', 'location': '', '
# ...

# %% [markdown]
# ### Get followers

# %%
followers = api.followers('jairbolsonaro', count=100)

# %%
[(follower._json['name'], follower._json['friends_count']) for follower in followers]
# Out:
# [('Bianca Soares', 13),
#  ('Pão Voador', 145),
#  ('Vanda Aguiar', 295),
#  ('Queequeg', 56),
#  ('Sueli Fernandes', 10),
#  ('Nicholas Rincón Chaves', 50),
#  ('Jessica Brito', 21),
#  ('eduardo abreu', 225),
#  ('Gustavo2K', 185),
#  ('𝑎 𝑛 𝑎✨', 291),
#  ('sofia', 121),
#  ('RogeriO Imaginátario', 120),
#  ('Jão jo⭐👑Lendo a pt 6 de JoJo', 87),
#  ('Docinn_🏳️\u200d🌈🏳️\u200d🌈', 106),
#  ('Reynaldo Marques', 78),
#  ('Denise Galana', 26),
#  ('Euclides Arruda', 20),
#  ('Republicadoshomens', 105),
#  ('Paulo ツ', 141),
#  ('Célia Santiago', 10),
#  ('Edson Pereira', 9),
#  ('Gabriel Sampaio', 113),
#  ('Alejandra', 343),
#  ('gab 🌓', 126),
#  ('manu🏳️\u200d🌈', 56),
#  ('rodrigomadc🥈', 890),
#  ('Elolinda', 27),
#  ('João Rodrigo Chaves Martins', 27),
#  ('Lestiça', 75),
#  ('Adriana Santos', 4),
#  ('Klleyton', 47),
#  ('Irineu', 4),
#  ('Gustavo Miranda Freitas', 107),
#  ('Luiz Levy Jr', 43),
#  ('Samuel Arthur', 68),
#  ('rafa.', 1038),
#  ('Sostenes Guerra', 5),
# ...

# %% [markdown]
# ### My tweets

# %%
timeline = api.home_timeline()
timeline
# Out:
# [Status(_api=<tweepy.api.API object at 0x0000021B6EADC7F0>, _json={'created_at': 'Mon Sep 07 19:03:44 +0000 2020', 'id': 1303046310426300416, 'id_str': '1303046310426300416', 'text': '#spotifynãofunfou #chateado #paçoca_yuri #portugal_ta_calor #feriado #lewagon', 'truncated': False, 'entities': {'hashtags': [{'text': 'spotifynãofunfou', 'indices': [0, 17]}, {'text': 'chateado', 'indices': [18, 27]}, {'text': 'paçoca_yuri', 'indices': [28, 40]}, {'text': 'portugal_ta_calor', 'indices': [41, 59]}, {'text': 'feriado', 'indices': [60, 68]}, {'text': 'lewagon', 'indices': [69, 77]}], 'symbols': [], 'user_mentions': [], 'urls': []}, 'source': '<a href="https://cs50.harvard.edu/" rel="nofollow">sentimentsAPI</a>', 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 127961954, 'id_str': '127961954', 'name': 'André Aguiar', 'screen_name': 'andreaguiarr', 'location': '', 
# ...

# %%
timeline[2]._json
# Out:
# {'created_at': 'Mon Sep 07 18:10:00 +0000 2020',
#  'id': 1303032786958254080,
#  'id_str': '1303032786958254080',
#  'text': '#SuperArquivo A história do imperador não terminou após a independência do Brasil. Veja as intrigas e acordos que s… https://t.co/bzFxegsuJb',
#  'truncated': True,
#  'entities': {'hashtags': [{'text': 'SuperArquivo', 'indices': [0, 13]}],
#   'symbols': [],
#   'user_mentions': [],
#   'urls': [{'url': 'https://t.co/bzFxegsuJb',
#     'expanded_url': 'https://twitter.com/i/web/status/1303032786958254080',
#     'display_url': 'twitter.com/i/web/status/1…',
#     'indices': [117, 140]}]},
#  'source': '<a href="https://about.twitter.com/products/tweetdeck" rel="nofollow">TweetDeck</a>',
#  'in_reply_to_status_id': None,
#  'in_reply_to_status_id_str': None,
#  'in_reply_to_user_id': None,
#  'in_reply_to_user_id_str': None,
#  'in_reply_to_screen_name': None,
#  'user': {'id': 17240425,
#   'id_str': '17240425',
#   'name': 'Superinteressante',
# ...

# %%
for i in range(10):
    print(timeline[i]._json['text'])
# Out:
# #spotifynãofunfou #chateado #paçoca_yuri #portugal_ta_calor #feriado #lewagon
# No Conexão VivaBem, Daniella Cicarelli contou para Jairo Bouer e o ortopedista Pedro Debieux como foi o processo de… https://t.co/wVm11kuUir
# #SuperArquivo A história do imperador não terminou após a independência do Brasil. Veja as intrigas e acordos que s… https://t.co/bzFxegsuJb
# Já se inscreveu no meu canal? https://t.co/9Ef0AaC7Dn https://t.co/hUFrNdYEdQ
# Wishing you a safe and healthy #LaborDay ☀️
#
# 📸: @SOFIAtelescope https://t.co/5mn2IfCpzj https://t.co/TPazT3hwrD
# Cicarelli: ?Meu limiar de dor é alto; só senti quando quebrei costelas? https://t.co/WC4Vy5cI6o
# Also knowing the safety inspector is crooked, the operator untrained, and politicians taking money from the theme p… https://t.co/A3QkxHIOcW
# Ah, I can hear it. The slow rhythmic clickety-clack, the wheels of the roller coaster car ascending that first rise… https://t.co/e7c65Yr7la
# https://t.co/FpWDpppwqa
# ...

# %% [markdown]
# ### Create friend

# %%
api.create_friendship('BarackObama')
# Out:
# User(_api=<tweepy.api.API object at 0x0000021B6EADC7F0>, _json={'id': 813286, 'id_str': '813286', 'name': 'Barack Obama', 'screen_name': 'BarackObama', 'location': 'Washington, DC', 'description': 'Dad, husband, President, citizen.', 'url': 'https://t.co/93Y27HEnnX', 'entities': {'url': {'urls': [{'url': 'https://t.co/93Y27HEnnX', 'expanded_url': 'https://www.obama.org/', 'display_url': 'obama.org', 'indices': [0, 23]}]}, 'description': {'urls': []}}, 'protected': False, 'followers_count': 122334774, 'friends_count': 601536, 'listed_count': 220388, 'created_at': 'Mon Mar 05 22:08:25 +0000 2007', 'favourites_count': 1, 'utc_offset': None, 'time_zone': None, 'geo_enabled': False, 'verified': True, 'statuses_count': 15919, 'lang': None, 'status': {'created_at': 'Mon Sep 07 17:01:07 +0000 2020', 'id': 1303015453544112129, 'id_str': '1303015453544112129', 'text': 'RT @JoeBiden: Today, we honor the generations of union workers who fought for the rights, power, wages, and benefits that buil
# ...

# %% [markdown]
# ### search for keywords

# %%
posts = api.search(q="ironhack", lang="en", count=100)
posts
# Out:
# [Status(_api=<tweepy.api.API object at 0x0000021B6EADC7F0>, _json={'created_at': 'Sun Sep 06 14:01:09 +0000 2020', 'id': 1302607774879227904, 'id_str': '1302607774879227904', 'text': 'RT @WomenWhoCode: 🎉 Our partner @ironhack is giving away $2,000 #scholarships for WWCode members to take their web development and UX/UI de…', 'truncated': False, 'entities': {'hashtags': [{'text': 'scholarships', 'indices': [64, 77]}], 'symbols': [], 'user_mentions': [{'screen_name': 'WomenWhoCode', 'name': 'Women Who Code', 'id': 345673106, 'id_str': '345673106', 'indices': [3, 16]}, {'screen_name': 'ironhack', 'name': 'Ironhack', 'id': 1551130856, 'id_str': '1551130856', 'indices': [32, 41]}], 'urls': []}, 'metadata': {'iso_language_code': 'en', 'result_type': 'recent'}, 'source': '<a href="https://rike.dev" rel="nofollow">friendly fem tech bot</a>', 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name
# ...

# %%
posts[0]._json['text']
# Out:
# RT @WomenWhoCode: 🎉 Our partner @ironhack is giving away $2,000 #scholarships for WWCode members to take their web development and UX/UI de…

# %%
posts[2]._json['text']

# %%
i = 5
print(posts[i]._json['text'])

print(posts[i]._json['entities']['hashtags'])

print(posts[i]._json['user']['name'])
# Out:
# RT @WomenWhoCode: 🎉 Our partner @ironhack is giving away $2,000 #scholarships for WWCode members to take their web development and UX/UI de…
# [{'text': 'scholarships', 'indices': [64, 77]}]
# María V. Ortiz

# %%
import re

for post in posts:
    if len(post._json['entities']['hashtags']): 
        if re.search('.*scholarships.*', post._json['entities']['hashtags'][0]['text'], 
                     flags=re.IGNORECASE):
            print(post._json['user']['name'], '-', post._json['user']['location'], post._json['text'], '\n')
# Out:
# FemTech_🖥👩🏽‍💻 - Berlin, Deutschland RT @WomenWhoCode: 🎉 Our partner @ironhack is giving away $2,000 #scholarships for WWCode members to take their web development and UX/UI de…
#
# Taylor Banks - Atlanta, GA RT @WomenWhoCode: 🎉 Our partner @ironhack is giving away $2,000 #scholarships for WWCode members to take their web development and UX/UI de…
#
# FemTech_🖥👩🏽‍💻 - Berlin, Deutschland RT @WomenWhoCode: 🎉 Our partner @ironhack is giving away $2,000 #scholarships for WWCode members to take their web development and UX/UI de…
#
# NearShoreTechnology - Puebla & Merida, MX RT @WomenWhoCode: 🎉 Our partner @ironhack is giving away $2,000 #scholarships for WWCode members to take their web development and UX/UI de…
#
# María V. Ortiz - Caracas, Venezuela RT @WomenWhoCode: 🎉 Our partner @ironhack is giving away $2,000 #scholarships for WWCode members to take their web development and UX/UI de…
#
# ...

# %% [markdown]
# ### Get user's timeline

# %%
tweets = api.user_timeline(screen_name = 'realDonaldTrump', count=2000)

# %%
tweets[5]._json['text']
# Out:
# 'RT @realDonaldTrump: Rochester N.Y., Brooklyn N.Y., Portland - All had bad nights, all weakly run by Radical Left Democrat Governors and Ma…'

# %% [markdown]
# ----

# %% [markdown]
# ## GoodReads
#
# https://www.goodreads.com/api

# %% [markdown]
# `!pip install Goodreads`

# %%
from goodreads import client
gc = client.GoodreadsClient(os.getenv('goodreads_key'), 
                            os.getenv('goodreads_secret'))

# %%
book = gc.book(1)
book
# Out:
# Harry Potter and the Half-Blood Prince (Harry Potter, #6)

# %%
type(book)
# Out:
# goodreads.book.GoodreadsBook

# %%
book.average_rating
# Out:
# '4.57'

# %%
book.title
# Out:
# 'Harry Potter and the Half-Blood Prince (Harry Potter, #6)'

# %%
book.similar_books
# Out:
# [Harry Potter and the Cursed Child: Parts One and Two (Harry Potter, #8),
#  Catching Fire (The Hunger Games, #2),
#  Mockingjay (The Hunger Games, #3),
#  New Moon (Twilight, #2),
#  Eclipse (Twilight, #3),
#  Breaking Dawn (Twilight, #4),
#  Harry Potter and the Chamber of Secrets: Sheet Music for Flute with C.D,
#  The Two Towers (The Lord of the Rings, #2),
#  The Sea of Monsters (Percy Jackson and the Olympians, #2),
#  The Return of the King (The Lord of the Rings, #3),
#  Fantastic Beasts and Where to Find Them (Hogwarts Library),
#  The Da Vinci Code (Robert Langdon, #2),
#  The Hobbit, or There and Back Again,
#  The Titan's Curse (Percy Jackson and the Olympians, #3),
#  The Last Olympian (Percy Jackson and the Olympians, #5),
#  Quidditch Through the Ages (Hogwarts Library),
#  The Lightning Thief (Percy Jackson and the Olympians, #1),
#  Insurgent (Divergent, #2)]

# %%
user = gc.user(3)

# %%
type(user)
# Out:
# goodreads.user.GoodreadsUser

# %%
user.name
# Out:
# 'Adrian'

# %%
user.user_name
# Out:
# 'sickpea'

# %%
gc.find_groups("star wars")
# Out:
# [OrderedDict([('id', '181895'),
#               ('access', 'public'),
#               ('users_count', '284'),
#               ('title', 'Star Wars Book Club'),
#               ('small_image_url',
#                'https://images.gr-assets.com/groups/1481652084p2/181895.jpg'),
#               ('image_url',
#                'https://images.gr-assets.com/groups/1481652084p3/181895.jpg'),
#               ('last_activity_at', 'Mon Sep 07 12:35:48 -0700 2020')]),
#  OrderedDict([('id', '142309'),
#               ('access', 'public'),
#               ('users_count', '14390'),
#               ('title', 'Underground Knowledge — A discussion group'),
#               ('small_image_url',
#                'https://images.gr-assets.com/groups/1472008617p2/142309.jpg'),
#               ('image_url',
#                'https://images.gr-assets.com/groups/1472008617p3/142309.jpg'),
#               ('last_activity_at', 'Mon Sep 07 12:09:31 -0700 2020')]),
#  OrderedDict([('id', '1115628'),
# ...

# %% [markdown]
# ## Trello

# %%
from trello import TrelloClient

client = TrelloClient(
    api_key=os.getenv('trello_key'),
    api_secret=os.getenv('trello_secret'),
    token=os.getenv('trello_token'),
)

# %%
client.list_boards()
# Out:
# [<Board Daily Task Management>,
#  <Board Geral>,
#  <Board IronHack Full-Time>,
#  <Board Teste>]

# %%
client.search('api')
# Out:
# [<Card Segunda-Feira>]

# %%
client.search('Parallel')
# Out:
# [<Card Quarta-Feira>]

# %%
card = client.search('Parallel')[0]
card
# Out:
# <Card Quarta-Feira>

# %%
try:
    [checklist.delete() for checklist in card.checklists]
    print('Deleted')
except:
    print('No checklists to delete')
# Out:
# No checklists to delete

# %%
card.add_checklist('Test Checklist', ['a','b','c'], itemstates=[False, True, False])
# Out:
# <Checklist 5f5691ab5f8c9f1e042aaab5>

# %%
card.checklists[0].delete()

# %%
client.add_board('New Board')
# Out:
# <Board New Board>

# %% [markdown]
# ----

# %% [markdown]
# postman

# %%
import requests

url = "https://api.spotify.com/v1/audio-features/198vEZJYqlOtiWw2e1mPmq"

payload = {}
headers = {
  'Accept': 'application/json',
  'Content-Type': 'application/json',
  'Authorization': 'Bearer BQDWiwfw96tpnJL92xHySjXYN3jK8X7Z1KSN4LK4VFpnVy-DkyEcWuxvS43pzfpffMLdZuWey5pN4zVOiWLy9Tbk-9_Xd1_WiHkoWHeSKO56iu6TodpDdUFwaSR5gWVKMG-j07aHXt_7KT6i6gGMgDJxljj-nqYYNs11mYLWSU85z39n-g'
}

response = requests.request("GET", url, headers=headers, data = payload)

# %%
response.json()
# Out:
# {'danceability': 0.662,
#  'energy': 0.9,
#  'key': 4,
#  'loudness': -4.3,
#  'mode': 1,
#  'speechiness': 0.107,
#  'acousticness': 0.508,
#  'instrumentalness': 0.000889,
#  'liveness': 0.345,
#  'valence': 0.84,
#  'tempo': 135.868,
#  'type': 'audio_features',
#  'id': '198vEZJYqlOtiWw2e1mPmq',
#  'uri': 'spotify:track:198vEZJYqlOtiWw2e1mPmq',
#  'track_href': 'https://api.spotify.com/v1/tracks/198vEZJYqlOtiWw2e1mPmq',
#  'analysis_url': 'https://api.spotify.com/v1/audio-analysis/198vEZJYqlOtiWw2e1mPmq',
#  'duration_ms': 182693,
#  'time_signature': 3}
