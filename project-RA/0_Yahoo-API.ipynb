# %% [markdown]
# # Installing/importing relevant packages

# %%
# !pip install yfinance

# %%
import yfinance as yf
import pandas as pd

# %% [markdown]
# # Gathering and parsing Yahoo Finance data - Pagseguro

# %%
#Check whether PagSeguro has distributed dividends or performed a stock split - either way it could affect 
#the stock price/volume
ps.actions
'''
No dividend/stock split performed over the last few years
PagSeguro's close daily price should reflect its value
'''
# Out:
# Empty DataFrame
# Columns: [Dividends, Stock Splits]
# Index: []

# %%
max_history = ps.history(period='max')
'''
max_history reflects the PagSeguro's daily stock price movement since its IPO on Jan./18
'''

# %%
max_history.to_csv('./final/final_stock_price.csv', sep=';')

# %% [markdown]
# # Gathering and parsing Yahoo Finance data - Peers

# %%
peers = 'PAGS STNE SQ CIEL3.SA ^GSPC ^BVSP'

# %%
data = yf.download(peers, start="2017-01-01", end="2020-09-15")
# Out:
# [*********************100%***********************]  6 of 6 completed

# %%
data
# Out:
#             Adj Close                                              \
#              CIEL3.SA       PAGS          SQ       STNE     ^BVSP
# Date
# 2017-01-02  18.427422        NaN         NaN        NaN   59589.0
# 2017-01-03  18.941414        NaN   13.810000        NaN   61814.0
# 2017-01-04  18.758993        NaN   14.250000        NaN   61589.0
# 2017-01-05  18.555162        NaN   14.560000        NaN   62071.0
# 2017-01-06  18.595928        NaN   15.000000        NaN   61665.0
# ...               ...        ...         ...        ...       ...
# 2020-09-08   4.700000  37.340000  139.110001  49.810001  100050.0
# 2020-09-09   4.690000  37.259998  144.210007  50.660000  101292.0
# 2020-09-10   4.640000  36.650002  141.070007  51.040001   98835.0
# 2020-09-11   4.440000  35.160000  137.449997  50.490002   98363.0
# 2020-09-14   4.750000  36.290001  144.399994  51.680000  100275.0
#
#                              Close                                    ...  \
#                   ^GSPC   CIEL3.SA       PAGS          SQ       STNE  ...
# Date                                                                  ...
# 2017-01-02          NaN  22.708300        NaN         NaN        NaN  ...
# 2017-01-03  2257.830078  23.341700        NaN   13.810000        NaN  ...
# 2017-01-04  2270.750000  23.008301        NaN   14.250000        NaN  ...
# 2017-01-05  2269.000000  22.758301        NaN   14.560000        NaN  ...
# 2017-01-06  2276.979980  22.808300        NaN   15.000000        NaN  ...
# ...                 ...        ...        ...         ...        ...  ...
# 2020-09-08  3331.840088   4.700000  37.340000  139.110001  49.810001  ...
# 2020-09-09  3398.959961   4.690000  37.259998  144.210007  50.660000  ...
# 2020-09-10  3339.189941   4.640000  36.650002  141.070007  51.040001  ...
# 2020-09-11  3340.969971   4.440000  35.160000  137.449997  50.490002  ...
# 2020-09-14  3383.540039   4.750000  36.290001  144.399994  51.680000  ...
#
#                   Open                                        Volume  \
#                     SQ       STNE     ^BVSP        ^GSPC    CIEL3.SA
# Date
# 2017-01-02         NaN        NaN   60227.0          NaN   2231160.0
# 2017-01-03   13.820000        NaN   59631.0  2251.570068   4989840.0
# 2017-01-04   13.860000        NaN   61811.0  2261.600098   3612600.0
# 2017-01-05   14.250000        NaN   61594.0  2268.179932   3741720.0
# 2017-01-06   14.560000        NaN   62072.0  2271.139893   3567000.0
# ...                ...        ...       ...          ...         ...
# 2020-09-08  137.009995  48.009998  101239.0  3371.879883  28027200.0
# 2020-09-09  145.649994  51.180000  100050.0  3369.820068  38421800.0
# 2020-09-10  147.020004  51.139999  101291.0  3412.560059  30933200.0
# 2020-09-11  143.910004  51.310001   98839.0  3352.699951  55194700.0
# 2020-09-14  140.070007  51.500000   98367.0  3363.560059  61649700.0
#
#
#                  PAGS          SQ       STNE      ^BVSP         ^GSPC
# Date
# 2017-01-02        NaN         NaN        NaN   808700.0           NaN
# 2017-01-03        NaN   3363900.0        NaN  3328300.0  3.770530e+09
# 2017-01-04        NaN   4977400.0        NaN  2840800.0  3.764890e+09
# 2017-01-05        NaN   5779800.0        NaN  3313000.0  3.761820e+09
# 2017-01-06        NaN   6382200.0        NaN  2374800.0  3.339890e+09
# ...               ...         ...        ...        ...           ...
# 2020-09-08  2216800.0  10681400.0  2872400.0  8479000.0  4.665600e+09
# 2020-09-09  1815700.0   9463600.0  3229000.0  7955600.0  3.920830e+09
# 2020-09-10  1042400.0   6711500.0  2750400.0  8894600.0  4.192250e+09
# 2020-09-11  1927500.0   8428400.0  1168400.0  9107900.0  3.704450e+09
# 2020-09-14  1626700.0   7754800.0  1491500.0  8182100.0  3.832130e+09
#
# [956 rows x 36 columns]

# %%
data.columns = [i[0]+'_'+i[1] for i in data.columns]

# %%
data.head()
# Out:
#             Adj Close_CIEL3.SA  Adj Close_PAGS  Adj Close_SQ  Adj Close_STNE  \
# Date
# 2017-01-02           18.427422             NaN           NaN             NaN
# 2017-01-03           18.941414             NaN         13.81             NaN
# 2017-01-04           18.758993             NaN         14.25             NaN
# 2017-01-05           18.555162             NaN         14.56             NaN
# 2017-01-06           18.595928             NaN         15.00             NaN
#
#             Adj Close_^BVSP  Adj Close_^GSPC  Close_CIEL3.SA  Close_PAGS  \
# Date
# 2017-01-02          59589.0              NaN       22.708300         NaN
# 2017-01-03          61814.0      2257.830078       23.341700         NaN
# 2017-01-04          61589.0      2270.750000       23.008301         NaN
# 2017-01-05          62071.0      2269.000000       22.758301         NaN
# 2017-01-06          61665.0      2276.979980       22.808300         NaN
#
#             Close_SQ  Close_STNE  ...  Open_SQ  Open_STNE  Open_^BVSP  \
# Date                              ...
# 2017-01-02       NaN         NaN  ...      NaN        NaN     60227.0
# 2017-01-03     13.81         NaN  ...    13.82        NaN     59631.0
# 2017-01-04     14.25         NaN  ...    13.86        NaN     61811.0
# 2017-01-05     14.56         NaN  ...    14.25        NaN     61594.0
# 2017-01-06     15.00         NaN  ...    14.56        NaN     62072.0
#
#              Open_^GSPC  Volume_CIEL3.SA  Volume_PAGS  Volume_SQ  Volume_STNE  \
# Date
# 2017-01-02          NaN        2231160.0          NaN        NaN          NaN
# 2017-01-03  2251.570068        4989840.0          NaN  3363900.0          NaN
# 2017-01-04  2261.600098        3612600.0          NaN  4977400.0          NaN
# 2017-01-05  2268.179932        3741720.0          NaN  5779800.0          NaN
# 2017-01-06  2271.139893        3567000.0          NaN  6382200.0          NaN
#
#             Volume_^BVSP  Volume_^GSPC
# Date
# 2017-01-02      808700.0           NaN
# 2017-01-03     3328300.0  3.770530e+09
# 2017-01-04     2840800.0  3.764890e+09
# 2017-01-05     3313000.0  3.761820e+09
# 2017-01-06     2374800.0  3.339890e+09
#
# [5 rows x 36 columns]

# %%
data.to_excel('./final/peers.xlsx')
